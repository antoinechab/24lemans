# %%
from bs4 import BeautifulSoup as bs

# %%
def getYearSoup(year):
    html_doc = open('./../datas/data_row/'+str(year)+'.txt', mode="r", encoding="utf-8").read()
    soup = bs(html_doc, 'html.parser')
    js  = soup.find_all("script")
    row_content = js[14]
    row_content = str(row_content)
    #je supprime tous les caractère avant l'appel à la fonction declareChamp
    row_content = row_content[row_content.find('clWDUtil'):]
    #je supprime tous les caractère avant le début du tableau de données
    row_content = row_content[row_content.find('['):]
    #je supprime tous les caractère après l'appel à la fonction declareChamp
    row_content = row_content.split('var _COL', 1)[0]
    #je supprime tous les caractère après la fin du tableau de données
    row_content = row_content.rsplit('],', 1)[0]
    #je supprime le premier charactère de la string (l'ouverture de tableau)
    row_content = row_content[1:]
    row_content_decoded = row_content.encode().decode('unicode_escape')
    return bs(row_content_decoded)

# %%
def get_value(text, id_str):
    currentString=text.find(id=id_str).get_text()
    try:
        return currentString.encode("windows-1252").decode('utf-8')
    except UnicodeError:
        return currentString

# %%
dataSet = {}

# %%
def buildYearDataset(year):
    yearSoup = getYearSoup(year)
    i=1
    row=len(dataSet)
    target="zrl_1_A48"
    while yearSoup.find(id=target) is not None:
        row+=1
        dataSet[row]={}
        dataSet[row]["car"] = get_value(yearSoup,"zrl_"+str(i)+"_A48")
        dataSet[row]["rank"] = i
        dataSet[row]["brand"] = get_value(yearSoup, "lzzrl_"+str(i)+"_A16")
        dataSet[row]["engine"] = get_value(yearSoup, "lzzrl_"+str(i)+"_A46")
        dataSet[row]["tires_brand"] = get_value(yearSoup, "zrl_"+str(i)+"_A10")
        dataSet[row]["category"] = get_value(yearSoup, "zrl_"+str(i)+"_A80")
        dataSet[row]["race_year"] = get_value(yearSoup, "zrl_"+str(i)+"_A20")
        dataSet[row]["try_rank"] = get_value(yearSoup, "zrl_"+str(i)+"_A50")
        dataSet[row]["try_speed"] = get_value(yearSoup, "zrl_"+str(i)+"_A51")
        dataSet[row]["race_rank"] = get_value(yearSoup, "zrl_"+str(i)+"_A49")
        dataSet[row]["race_turn"] = get_value(yearSoup, "zrl_"+str(i)+"_A54")
        dataSet[row]["race_mean"] = get_value(yearSoup, "zrl_"+str(i)+"_A82")
        dataSet[row]["race_best_turn"] = get_value(yearSoup, "zrl_"+str(i)+"_A56")
        dataSet[row]["race_max_speed"] = get_value(yearSoup, "zrl_"+str(i)+"_A8")
        dataSet[row]["pilot_1"] = get_value(yearSoup, "zrl_"+str(i)+"_A30")
        dataSet[row]["pilot_2"] = get_value(yearSoup, "zrl_"+str(i)+"_A31")
        dataSet[row]["pilot_3"] = get_value(yearSoup, "zrl_"+str(i)+"_A32")
        i+=1
        target="zrl_"+str(i)+"_A48"

# %%
yearsKeys=[1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1937, 1938, 1939, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
for year in yearsKeys:
    buildYearDataset(year)

# %%
dataSet
# Out:
# {'car': 'Chenard et Walcker Sport',
#  'rank': 1,
#  'brand': '',
#  'engine': 'Moteur Chenard et Walker L4 2978cc',
#  'tires_brand': 'Michelin',
#  'category': '2001 a 3000',
#  'race_year': '1923',
#  'try_rank': 'pas de chrono',
#  'try_speed': '',
#  'race_rank': '1er-1er 2001 a 3000',
#  'race_turn': '128 Tours - 2209.536 Km ',
#  'race_mean': 'Moyenne 92.064 km/h',
#  'race_best_turn': '09:59',
#  'race_max_speed': '',
#  'pilot_1': 'André Lagache',
#  'pilot_2': 'René Léonard',
#  'pilot_3': '',
#  1923: {1: {'car': 'Chenard et Walcker Sport',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 2978cc',
#    'tires_brand': 'Michelin',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '1er-1er 2001 a 3000',
#    'race_turn': '128 Tours - 2209.536 Km ',
#    'race_mean': 'Moyenne 92.064 km/h',
#    'race_best_turn': '09:59',
#    'race_max_speed': '',
#    'pilot_1': 'André Lagache',
#    'pilot_2': 'René Léonard',
#    'pilot_3': ''},
#   2: {'car': 'Chenard et Walcker Sport',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 2978cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '2ème-2e 2001 a 3000',
#    'race_turn': '124 Tours - 2140.488 Km ',
#    'race_mean': 'Moyenne 89.187 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raoul Bachmann',
#    'pilot_2': 'Christian Dauvergne',
#    'pilot_3': ''},
#   3: {'car': 'Bignan 11 HP Desmo',
#    'brand': '',
#    'engine': 'Moteur Bignan L4 1979cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '3ème-1er 1501 a 2000',
#    'race_turn': '120 Tours - 2071.44 Km ',
#    'race_mean': 'Moyenne 86.308 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raymond de Tornaco',
#    'pilot_2': 'Victor Gros',
#    'pilot_3': ''},
#   4: {'car': 'Excelsior Adex C',
#    'brand': '',
#    'engine': 'Moteur Excelsior L6 5343cc',
#    'tires_brand': '',
#    'category': '5001 a 8000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-1er 5001 a 8000',
#    'race_turn': '112 Tours - 1933.344 Km ',
#    'race_mean': 'Moyenne 80.556 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'André Dils',
#    'pilot_2': 'Nicolas Caerels',
#    'pilot_3': ''},
#   5: {'car': 'Bentley Sport',
#    'brand': '',
#    'engine': 'Moteur Bentley L4 2996cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-3e 2001 a 3000',
#    'race_turn': '112 Tours - 1933.344 Km ',
#    'race_mean': 'Moyenne 80.556 km/h',
#    'race_best_turn': '09:39',
#    'race_max_speed': '',
#    'pilot_1': 'John Duff',
#    'pilot_2': 'Frank Clement',
#    'pilot_3': ''},
#   6: {'car': 'Bignan 11 HP Commercial',
#    'brand': '',
#    'engine': 'Moteur Bignan L4 1979cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-2e 1501 a 2000',
#    'race_turn': '112 Tours - 1933.344 Km ',
#    'race_mean': 'Moyenne 80.556 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Philippe de Marne',
#    'pilot_2': 'Jean Martin',
#    'pilot_3': ''},
#   7: {'car': 'Chenard et Walcker 15 HP Tourisme',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 2978cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '7ème-4e 2001 a 3000',
#    'race_turn': '110 Tours - 1898.82 Km ',
#    'race_mean': 'Moyenne 79.117 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Fernand Bachmann',
#    'pilot_2': 'Raymond Glaszmann',
#    'pilot_3': ''},
#   8: {'car': 'Lorraine-Dietrich B3-6',
#    'brand': '',
#    'engine': 'Moteur Lorraine-Dietrich L6 3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '8ème-1er 3001 a 5000',
#    'race_turn': '109 Tours - 1881.56 Km ',
#    'race_mean': 'Moyenne 78.4 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henry de Courcelles',
#    'pilot_2': 'André Rossignol',
#    'pilot_3': ''},
#   9: {'car': 'Excelsior Adex C',
#    'brand': '',
#    'engine': 'Moteur Excelsior L6 5343cc',
#    'tires_brand': '',
#    'category': '5001 a 8000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '9ème-2e 5001 a 8000',
#    'race_turn': '106 Tours - 1829.772 Km ',
#    'race_mean': 'Moyenne 76.24 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Gonzague Lecureul',
#    'pilot_2': ' Flaud',
#    'pilot_3': ''},
#   10: {'car': 'Bugatti Type 13 Brescia 16S',
#    'brand': '',
#    'engine': 'Moteur Bugatti L4 1495cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '10ème-1er 1001 a 1500',
#    'race_turn': '104 Tours - 1795.248 Km ',
#    'race_mean': 'Moyenne 74.802 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Max de Pourtales',
#    'pilot_2': 'Sosthènes de la Rochefoucauld',
#    'pilot_3': ''},
#   11: {'car': 'Brasier TC4',
#    'brand': '',
#    'engine': 'Moteur Brasier L4 2092cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '11ème-5e 2001 a 3000',
#    'race_turn': '100 Tours - 1708.938 Km ',
#    'race_mean': 'Moyenne 71.205 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'René Migeot',
#    'pilot_2': 'Eugène Verpault',
#    'pilot_3': ''},
#   12: {'car': 'Delage DE 11 HP',
#    'brand': '',
#    'engine': 'Moteur Delage L4 2116cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '12ème-6e 2001 a 3000',
#    'race_turn': '98 Tours - 1691.676 Km ',
#    'race_mean': 'Moyenne 70.486 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Paul Torchy',
#    'pilot_2': 'Charles Belben',
#    'pilot_3': ''},
#   13: {'car': 'Salmson AL',
#    'brand': '',
#    'engine': 'Moteur Salmson L4 1086cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '12ème-1er 751 a 1100',
#    'race_turn': '98 Tours - 1691.676 Km ',
#    'race_mean': 'Moyenne 70.486 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Lucien Desvaux',
#    'pilot_2': 'Georges Casse',
#    'pilot_3': ''},
#   14: {'car': 'Montier Spécial',
#    'brand': '',
#    'engine': 'Moteur Ford L4 2008cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '14ème-7e 2001 a 3000',
#    'race_turn': '97 Tours - 1674.414 Km ',
#    'race_mean': 'Moyenne 69.767 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Charles Montier',
#    'pilot_2': 'Albert Ouriou',
#    'pilot_3': ''},
#   15: {'car': 'Georges Irat 4 A3',
#    'brand': '',
#    'engine': 'Moteur Georges Irat L4 1986cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '15ème-2e 751 a 1100',
#    'race_turn': '93 Tours - 1605.366 Km ',
#    'race_mean': 'Moyenne 66.89 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Maurice Cappé',
#    'pilot_2': 'Jean Douarinou',
#    'pilot_3': ''},
#   16: {'car': 'Salmson AL',
#    'brand': '',
#    'engine': 'Moteur Salmson L4 1086cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '15ème-3e 751 a 1100',
#    'race_turn': '93 Tours - 1605.366 Km ',
#    'race_mean': 'Moyenne 66.89 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Robert Benoist',
#    'pilot_2': 'Luis Ramon Bueno',
#    'pilot_3': ''},
#   17: {'car': 'Rolland Pilain B 22',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 2297cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '17ème-8e 2001 a 3000',
#    'race_turn': '92 Tours - 1588.104 Km ',
#    'race_mean': 'Moyenne 66.171 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Gaston Delalande',
#    'pilot_2': 'Jean de Marguenat',
#    'pilot_3': ''},
#   18: {'car': 'Amilcar CV',
#    'brand': '',
#    'engine': 'Moteur Amilcar L4 1003cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '18ème-4e 751 a 1100',
#    'race_turn': '89 Tours - 1536.318 Km ',
#    'race_mean': 'Moyenne 64.013 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Maurice Boutmy',
#    'pilot_2': 'Jérôme Marcadanti',
#    'pilot_3': ''},
#   19: {'car': 'Lorraine-Dietrich B3-6',
#    'brand': '',
#    'engine': 'Moteur Lorraine-Dietrich L6 3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '19ème-2e 3001 a 5000',
#    'race_turn': '88 Tours - 1519.056 Km ',
#    'race_mean': 'Moyenne 63.294 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Robert Bloch',
#    'pilot_2': 'Henri Stalter',
#    'pilot_3': ''},
#   20: {'car': 'Berliet VH 12 HP',
#    'brand': '',
#    'engine': 'Moteur Berliet L4 2617cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '19ème-9e 2001 a 3000',
#    'race_turn': '88 Tours - 1519.056 Km ',
#    'race_mean': 'Moyenne 63.294 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Elie Redon',
#    'pilot_2': ' Prost',
#    'pilot_3': ''},
#   21: {'car': 'Rolland Pilain R',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 2224cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '21ème-10e 2001 a 3000',
#    'race_turn': '84 Tours - 1450.008 Km ',
#    'race_mean': 'Moyenne 60.417 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Georges Guignard',
#    'pilot_2': 'Louis Sire',
#    'pilot_3': ''},
#   22: {'car': 'Bugatti Type 13 Brescia 16S',
#    'brand': '',
#    'engine': 'Moteur Bugatti L4 1495cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '22ème-2e 1001 a 1500',
#    'race_turn': '82 Tours - 1415.484 Km ',
#    'race_mean': 'Moyenne 58.978 km/h',
#    'race_best_turn': '11:30',
#    'race_max_speed': '',
#    'pilot_1': 'René Marie',
#    'pilot_2': 'Louis Pichard',
#    'pilot_3': ''},
#   23: {'car': 'Corre la Licorne EV 12 CV',
#    'brand': '',
#    'engine': 'Moteur Ballot L4 1393cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '23ème-3e 1001 a 1500',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': 'Moyenne 56.82 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Louis Balart',
#    'pilot_2': 'Paul Drouin',
#    'pilot_3': ''},
#   24: {'car': 'Rolland Pilain RP',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1925cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '23ème-3e 1501 a 2000',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': 'Moyenne 56.82 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Jean Pouzet',
#    'pilot_2': 'Edmond Pichon',
#    'pilot_3': ''},
#   25: {'car': 'Rolland Pilain RP',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1925cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '23ème-4e 1501 a 2000',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': 'Moyenne 56.82 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Jude Robin',
#    'pilot_2': 'Gérard Marinier',
#    'pilot_3': ''},
#   26: {'car': 'Vinot Deguingand BP 10 HP',
#    'brand': '',
#    'engine': 'Moteur Vinot Deguingan L4 1847cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '26ème-5e 1501 a 2000',
#    'race_turn': '77 Tours - 1329.174 Km ',
#    'race_mean': 'Moyenne 55.382 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Léon Molon',
#    'pilot_2': 'Lucien Molon',
#    'pilot_3': ''},
#   27: {'car': 'Brasier TB4',
#    'brand': '',
#    'engine': 'Moteur Brasier L4 2092cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '27ème-11e 2001 a 3000',
#    'race_turn': '76 Tours - 1311.912 Km ',
#    'race_mean': 'Moyenne 54.663 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Léopold Jouguet',
#    'pilot_2': 'Pierre Maillon',
#    'pilot_3': ''},
#   28: {'car': 'Corre la Licorne EV 12 CV',
#    'brand': '',
#    'engine': 'Moteur Ballot L4 2001cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '28ème-12e 2001 a 3000',
#    'race_turn': '74 Tours - 1277.388 Km ',
#    'race_mean': 'Moyenne 53.224 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Albert Colomb',
#    'pilot_2': 'Waldemar Lestienne',
#    'pilot_3': ''},
#   29: {'car': 'Georges Irat 4 A3',
#    'brand': '',
#    'engine': 'Moteur Georges Irat L4 1990cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '29ème-6e 1501 a 2000',
#    'race_turn': '73 Tours - 1260.126 Km ',
#    'race_mean': 'Moyenne 52.505 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': ' Milhaud',
#    'pilot_2': 'Pierre Malleveau',
#    'pilot_3': ''},
#   30: {'car': 'SARA ATS',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1098cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '30ème-5e 751 a 1100',
#    'race_turn': '57 Tours - 983.934 Km ',
#    'race_mean': 'Moyenne 40.997 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Lucien Erb',
#    'pilot_2': 'Robert Battagliola',
#    'pilot_3': ''},
#   31: {'car': 'Lorraine-Dietrich B3-6',
#    'brand': '',
#    'engine': 'Moteur Lorraine-Dietrich L6 3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 50 Tours',
#    'race_turn': '50 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henri Stoffel',
#    'pilot_2': 'René Labouchère',
#    'pilot_3': ''},
#   32: {'car': 'Berliet VH 12 HP',
#    'brand': '',
#    'engine': 'Moteur Berliet L4 2617cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 44 Tours',
#    'race_turn': '44 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Roland Jacquot',
#    'pilot_2': 'Théodore Ribail',
#    'pilot_3': ''},
#   33: {'car': 'SARA ATS',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1098cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 14 Tours',
#    'race_turn': '14 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'François Piazzoli',
#    'pilot_2': 'André Marandet',
#    'pilot_3': ''},
#   34: {'car': 'Voisin ',
#    'brand': '',
#    'engine': 'Moteur   3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Non partant-3001 a 5000',
#    'race_turn': '0 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': '',
#    'pilot_2': '',
#    'pilot_3': ''}},
#  1924: {1: {'car': 'Chenard et Walcker Sport',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 2978cc',
#    'tires_brand': 'Michelin',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '1er-1er 2001 a 3000',
#    'race_turn': '128 Tours - 2209.536 Km ',
#    'race_mean': 'Moyenne 92.064 km/h',
#    'race_best_turn': '09:59',
#    'race_max_speed': '',
#    'pilot_1': 'André Lagache',
#    'pilot_2': 'René Léonard',
#    'pilot_3': ''},
#   2: {'car': 'Chenard et Walcker Sport',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 2978cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '2ème-2e 2001 a 3000',
#    'race_turn': '124 Tours - 2140.488 Km ',
#    'race_mean': 'Moyenne 89.187 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raoul Bachmann',
#    'pilot_2': 'Christian Dauvergne',
#    'pilot_3': ''},
#   3: {'car': 'Bignan 11 HP Desmo',
#    'brand': '',
#    'engine': 'Moteur Bignan L4 1979cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '3ème-1er 1501 a 2000',
#    'race_turn': '120 Tours - 2071.44 Km ',
#    'race_mean': 'Moyenne 86.308 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raymond de Tornaco',
#    'pilot_2': 'Victor Gros',
#    'pilot_3': ''},
#   4: {'car': 'Excelsior Adex C',
#    'brand': '',
#    'engine': 'Moteur Excelsior L6 5343cc',
#    'tires_brand': '',
#    'category': '5001 a 8000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-1er 5001 a 8000',
#    'race_turn': '112 Tours - 1933.344 Km ',
#    'race_mean': 'Moyenne 80.556 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'André Dils',
#    'pilot_2': 'Nicolas Caerels',
#    'pilot_3': ''},
#   5: {'car': 'Bentley Sport',
#    'brand': '',
#    'engine': 'Moteur Bentley L4 2996cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-3e 2001 a 3000',
#    'race_turn': '112 Tours - 1933.344 Km ',
#    'race_mean': 'Moyenne 80.556 km/h',
#    'race_best_turn': '09:39',
#    'race_max_speed': '',
#    'pilot_1': 'John Duff',
#    'pilot_2': 'Frank Clement',
#    'pilot_3': ''},
#   6: {'car': 'Bignan 11 HP Commercial',
#    'brand': '',
#    'engine': 'Moteur Bignan L4 1979cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-2e 1501 a 2000',
#    'race_turn': '112 Tours - 1933.344 Km ',
#    'race_mean': 'Moyenne 80.556 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Philippe de Marne',
#    'pilot_2': 'Jean Martin',
#    'pilot_3': ''},
#   7: {'car': 'Chenard et Walcker 15 HP Tourisme',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 2978cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '7ème-4e 2001 a 3000',
#    'race_turn': '110 Tours - 1898.82 Km ',
#    'race_mean': 'Moyenne 79.117 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Fernand Bachmann',
#    'pilot_2': 'Raymond Glaszmann',
#    'pilot_3': ''},
#   8: {'car': 'Lorraine-Dietrich B3-6',
#    'brand': '',
#    'engine': 'Moteur Lorraine-Dietrich L6 3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '8ème-1er 3001 a 5000',
#    'race_turn': '109 Tours - 1881.56 Km ',
#    'race_mean': 'Moyenne 78.4 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henry de Courcelles',
#    'pilot_2': 'André Rossignol',
#    'pilot_3': ''},
#   9: {'car': 'Excelsior Adex C',
#    'brand': '',
#    'engine': 'Moteur Excelsior L6 5343cc',
#    'tires_brand': '',
#    'category': '5001 a 8000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '9ème-2e 5001 a 8000',
#    'race_turn': '106 Tours - 1829.772 Km ',
#    'race_mean': 'Moyenne 76.24 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Gonzague Lecureul',
#    'pilot_2': ' Flaud',
#    'pilot_3': ''},
#   10: {'car': 'Bugatti Type 13 Brescia 16S',
#    'brand': '',
#    'engine': 'Moteur Bugatti L4 1495cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '10ème-1er 1001 a 1500',
#    'race_turn': '104 Tours - 1795.248 Km ',
#    'race_mean': 'Moyenne 74.802 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Max de Pourtales',
#    'pilot_2': 'Sosthènes de la Rochefoucauld',
#    'pilot_3': ''},
#   11: {'car': 'Brasier TC4',
#    'brand': '',
#    'engine': 'Moteur Brasier L4 2092cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '11ème-5e 2001 a 3000',
#    'race_turn': '100 Tours - 1708.938 Km ',
#    'race_mean': 'Moyenne 71.205 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'René Migeot',
#    'pilot_2': 'Eugène Verpault',
#    'pilot_3': ''},
#   12: {'car': 'Delage DE 11 HP',
#    'brand': '',
#    'engine': 'Moteur Delage L4 2116cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '12ème-6e 2001 a 3000',
#    'race_turn': '98 Tours - 1691.676 Km ',
#    'race_mean': 'Moyenne 70.486 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Paul Torchy',
#    'pilot_2': 'Charles Belben',
#    'pilot_3': ''},
#   13: {'car': 'Salmson AL',
#    'brand': '',
#    'engine': 'Moteur Salmson L4 1086cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '12ème-1er 751 a 1100',
#    'race_turn': '98 Tours - 1691.676 Km ',
#    'race_mean': 'Moyenne 70.486 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Lucien Desvaux',
#    'pilot_2': 'Georges Casse',
#    'pilot_3': ''},
#   14: {'car': 'Montier Spécial',
#    'brand': '',
#    'engine': 'Moteur Ford L4 2008cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '14ème-7e 2001 a 3000',
#    'race_turn': '97 Tours - 1674.414 Km ',
#    'race_mean': 'Moyenne 69.767 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Charles Montier',
#    'pilot_2': 'Albert Ouriou',
#    'pilot_3': ''},
#   15: {'car': 'Georges Irat 4 A3',
#    'brand': '',
#    'engine': 'Moteur Georges Irat L4 1986cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '15ème-2e 751 a 1100',
#    'race_turn': '93 Tours - 1605.366 Km ',
#    'race_mean': 'Moyenne 66.89 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Maurice Cappé',
#    'pilot_2': 'Jean Douarinou',
#    'pilot_3': ''},
#   16: {'car': 'Salmson AL',
#    'brand': '',
#    'engine': 'Moteur Salmson L4 1086cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '15ème-3e 751 a 1100',
#    'race_turn': '93 Tours - 1605.366 Km ',
#    'race_mean': 'Moyenne 66.89 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Robert Benoist',
#    'pilot_2': 'Luis Ramon Bueno',
#    'pilot_3': ''},
#   17: {'car': 'Rolland Pilain B 22',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 2297cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '17ème-8e 2001 a 3000',
#    'race_turn': '92 Tours - 1588.104 Km ',
#    'race_mean': 'Moyenne 66.171 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Gaston Delalande',
#    'pilot_2': 'Jean de Marguenat',
#    'pilot_3': ''},
#   18: {'car': 'Amilcar CV',
#    'brand': '',
#    'engine': 'Moteur Amilcar L4 1003cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '18ème-4e 751 a 1100',
#    'race_turn': '89 Tours - 1536.318 Km ',
#    'race_mean': 'Moyenne 64.013 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Maurice Boutmy',
#    'pilot_2': 'Jérôme Marcadanti',
#    'pilot_3': ''},
#   19: {'car': 'Lorraine-Dietrich B3-6',
#    'brand': '',
#    'engine': 'Moteur Lorraine-Dietrich L6 3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '19ème-2e 3001 a 5000',
#    'race_turn': '88 Tours - 1519.056 Km ',
#    'race_mean': 'Moyenne 63.294 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Robert Bloch',
#    'pilot_2': 'Henri Stalter',
#    'pilot_3': ''},
#   20: {'car': 'Berliet VH 12 HP',
#    'brand': '',
#    'engine': 'Moteur Berliet L4 2617cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '19ème-9e 2001 a 3000',
#    'race_turn': '88 Tours - 1519.056 Km ',
#    'race_mean': 'Moyenne 63.294 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Elie Redon',
#    'pilot_2': ' Prost',
#    'pilot_3': ''},
#   21: {'car': 'Rolland Pilain R',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 2224cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '21ème-10e 2001 a 3000',
#    'race_turn': '84 Tours - 1450.008 Km ',
#    'race_mean': 'Moyenne 60.417 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Georges Guignard',
#    'pilot_2': 'Louis Sire',
#    'pilot_3': ''},
#   22: {'car': 'Bugatti Type 13 Brescia 16S',
#    'brand': '',
#    'engine': 'Moteur Bugatti L4 1495cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '22ème-2e 1001 a 1500',
#    'race_turn': '82 Tours - 1415.484 Km ',
#    'race_mean': 'Moyenne 58.978 km/h',
#    'race_best_turn': '11:30',
#    'race_max_speed': '',
#    'pilot_1': 'René Marie',
#    'pilot_2': 'Louis Pichard',
#    'pilot_3': ''},
#   23: {'car': 'Corre la Licorne EV 12 CV',
#    'brand': '',
#    'engine': 'Moteur Ballot L4 1393cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '23ème-3e 1001 a 1500',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': 'Moyenne 56.82 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Louis Balart',
#    'pilot_2': 'Paul Drouin',
#    'pilot_3': ''},
#   24: {'car': 'Rolland Pilain RP',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1925cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '23ème-3e 1501 a 2000',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': 'Moyenne 56.82 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Jean Pouzet',
#    'pilot_2': 'Edmond Pichon',
#    'pilot_3': ''},
#   25: {'car': 'Rolland Pilain RP',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1925cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '23ème-4e 1501 a 2000',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': 'Moyenne 56.82 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Jude Robin',
#    'pilot_2': 'Gérard Marinier',
#    'pilot_3': ''},
#   26: {'car': 'Vinot Deguingand BP 10 HP',
#    'brand': '',
#    'engine': 'Moteur Vinot Deguingan L4 1847cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '26ème-5e 1501 a 2000',
#    'race_turn': '77 Tours - 1329.174 Km ',
#    'race_mean': 'Moyenne 55.382 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Léon Molon',
#    'pilot_2': 'Lucien Molon',
#    'pilot_3': ''},
#   27: {'car': 'Brasier TB4',
#    'brand': '',
#    'engine': 'Moteur Brasier L4 2092cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '27ème-11e 2001 a 3000',
#    'race_turn': '76 Tours - 1311.912 Km ',
#    'race_mean': 'Moyenne 54.663 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Léopold Jouguet',
#    'pilot_2': 'Pierre Maillon',
#    'pilot_3': ''},
#   28: {'car': 'Corre la Licorne EV 12 CV',
#    'brand': '',
#    'engine': 'Moteur Ballot L4 2001cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '28ème-12e 2001 a 3000',
#    'race_turn': '74 Tours - 1277.388 Km ',
#    'race_mean': 'Moyenne 53.224 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Albert Colomb',
#    'pilot_2': 'Waldemar Lestienne',
#    'pilot_3': ''},
#   29: {'car': 'Georges Irat 4 A3',
#    'brand': '',
#    'engine': 'Moteur Georges Irat L4 1990cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '29ème-6e 1501 a 2000',
#    'race_turn': '73 Tours - 1260.126 Km ',
#    'race_mean': 'Moyenne 52.505 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': ' Milhaud',
#    'pilot_2': 'Pierre Malleveau',
#    'pilot_3': ''},
#   30: {'car': 'SARA ATS',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1098cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '30ème-5e 751 a 1100',
#    'race_turn': '57 Tours - 983.934 Km ',
#    'race_mean': 'Moyenne 40.997 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Lucien Erb',
#    'pilot_2': 'Robert Battagliola',
#    'pilot_3': ''},
#   31: {'car': 'Lorraine-Dietrich B3-6',
#    'brand': '',
#    'engine': 'Moteur Lorraine-Dietrich L6 3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 50 Tours',
#    'race_turn': '50 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henri Stoffel',
#    'pilot_2': 'René Labouchère',
#    'pilot_3': ''},
#   32: {'car': 'Berliet VH 12 HP',
#    'brand': '',
#    'engine': 'Moteur Berliet L4 2617cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 44 Tours',
#    'race_turn': '44 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Roland Jacquot',
#    'pilot_2': 'Théodore Ribail',
#    'pilot_3': ''},
#   33: {'car': 'SARA ATS',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1098cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 14 Tours',
#    'race_turn': '14 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'François Piazzoli',
#    'pilot_2': 'André Marandet',
#    'pilot_3': ''},
#   34: {'car': 'Voisin ',
#    'brand': '',
#    'engine': 'Moteur   3445cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1923',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Non partant-3001 a 5000',
#    'race_turn': '0 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': '',
#    'pilot_2': '',
#    'pilot_3': ''}},
#  1925: {1: {'car': 'Bentley Sport',
#    'brand': '',
#    'engine': 'Moteur Bentley L4 2995cc',
#    'tires_brand': 'Dunlop',
#    'category': '2001 a 3000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '1er-1er 2001 a 3000',
#    'race_turn': '120 Tours - 2077.34 Km ',
#    'race_mean': 'Moyenne 86.555 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'John Duff',
#    'pilot_2': 'Frank Clement',
#    'pilot_3': ''},
#   2: {'car': 'La Lorraine B3-6',
#    'brand': '',
#    'engine': 'Moteur La Lorraine L6 3446cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '2ème-1er 3001 a 5000',
#    'race_turn': '119 Tours - 2061.41 Km ',
#    'race_mean': 'Moyenne 85.892 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henri Stoffel',
#    'pilot_2': 'Edouard Brisson',
#    'pilot_3': ''},
#   3: {'car': 'La Lorraine B3-6',
#    'brand': '',
#    'engine': 'Moteur La Lorraine L6 3446cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '3ème-2e 3001 a 5000',
#    'race_turn': '119 Tours - 2055.11 Km ',
#    'race_mean': 'Moyenne 85.629 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henry de Courcelles',
#    'pilot_2': 'André Rossignol',
#    'pilot_3': ''},
#   4: {'car': 'Chenard et Walcker ',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 1973cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '4ème-1er 1501 a 2000',
#    'race_turn': '111 Tours - 1918.07 Km ',
#    'race_mean': 'Moyenne 79.919 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'André Pisart',
#    'pilot_2': 'Joseph Chavée',
#    'pilot_3': ''},
#   5: {'car': 'Chenard et Walcker ',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 1973cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '5ème-2e 1501 a 2000',
#    'race_turn': '108 Tours - 1875.91 Km ',
#    'race_mean': 'Moyenne 78.163 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Rafael Manso de Zùñiga',
#    'pilot_2': 'Christian Dauvergne',
#    'pilot_3': ''},
#   6: {'car': 'Rolland Pilain C 23',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1992cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '6ème-3e 1501 a 2000',
#    'race_turn': '106 Tours - 1842.466 Km ',
#    'race_mean': 'Moyenne 76.769 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Gaston Delalande',
#    'pilot_2': 'Georges Guignard',
#    'pilot_3': ''},
#   7: {'car': 'Brasier ',
#    'brand': '',
#    'engine': 'Moteur Brasier L4 2092cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '7ème-2e 2001 a 3000',
#    'race_turn': '106 Tours - 1832.5 Km ',
#    'race_mean': 'Moyenne 76.354 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Eugène Verpault',
#    'pilot_2': 'Marcel Delabarre',
#    'pilot_3': ''},
#   8: {'car': 'Brasier ',
#    'brand': '',
#    'engine': 'Moteur Brasier L4 2092cc',
#    'tires_brand': '',
#    'category': '2001 a 3000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '8ème-3e 2001 a 3000',
#    'race_turn': '104 Tours - 1810.42 Km ',
#    'race_mean': 'Moyenne 75.434 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Léopold Jouguet',
#    'pilot_2': 'René Migeot',
#    'pilot_3': ''},
#   9: {'car': 'Rolland Pilain C 23',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1992cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '9ème-4e 1501 a 2000',
#    'race_turn': '104 Tours - 1800.37 Km ',
#    'race_mean': 'Moyenne 75.015 km/h',
#    'race_best_turn': '10:20',
#    'race_max_speed': '',
#    'pilot_1': 'Louis Sire',
#    'pilot_2': 'Louis Tremel',
#    'pilot_3': ''},
#   10: {'car': 'Bignan ',
#    'brand': '',
#    'engine': 'Moteur Bignan L4 1979cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '10ème-5e 1501 a 2000',
#    'race_turn': '102 Tours - 1766.82 Km ',
#    'race_mean': 'Moyenne 73.617 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raymond de Tornaco',
#    'pilot_2': 'Barthélémy Bruyère',
#    'pilot_3': ''},
#   11: {'car': 'Aries 8-10 CV',
#    'brand': '',
#    'engine': 'Moteur Aries L4 1085cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '11ème-1er 751 a 1100',
#    'race_turn': '91 Tours - 1576.69 Km ',
#    'race_mean': 'Moyenne 65.695 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henri Lapierre',
#    'pilot_2': 'Fernand Gabriel',
#    'pilot_3': ''},
#   12: {'car': 'SARA ',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1099cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '12ème-2e 751 a 1100',
#    'race_turn': '89 Tours - 1541.37 Km ',
#    'race_mean': 'Moyenne 64.224 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'André Marandet',
#    'pilot_2': 'François Piazzoli',
#    'pilot_3': ''},
#   13: {'car': 'Aries 8-10 CV',
#    'brand': '',
#    'engine': 'Moteur Aries L4 1085cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '13ème-3e 751 a 1100',
#    'race_turn': '89 Tours - 1540.87 Km ',
#    'race_mean': 'Moyenne 64.202 km/h',
#    'race_best_turn': '10:50.7',
#    'race_max_speed': '',
#    'pilot_1': 'Louis Rigal',
#    'pilot_2': 'Roger Delano',
#    'pilot_3': ''},
#   14: {'car': 'Amilcar CV',
#    'brand': '',
#    'engine': 'Moteur Amilcar L4 1004cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': '14ème-4e 751 a 1100',
#    'race_turn': '87 Tours - 1508.3 Km ',
#    'race_mean': 'Moyenne 62.845 km/h',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Maurice Boutmy',
#    'pilot_2': 'Jérôme Marcadanti',
#    'pilot_3': ''},
#   15: {'car': 'Chenard et Walcker ',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 1496cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Non classe.-1001 a 1500',
#    'race_turn': '84 Tours - 1450.008 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Pierre Bacqueyrisses',
#    'pilot_2': 'Georges Delaroche',
#    'pilot_3': ''},
#   16: {'car': 'Alba ',
#    'brand': '',
#    'engine': 'Moteur Alba L4 1481cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Non classe.-1001 a 1500',
#    'race_turn': '79 Tours - 1363.698 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raoul Roret',
#    'pilot_2': 'Gabriel Hatton',
#    'pilot_3': ''},
#   17: {'car': 'La Lorraine B3-6',
#    'brand': '',
#    'engine': 'Moteur La Lorraine L6 3446cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 112 Tours',
#    'race_turn': '112 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Robert Bloch',
#    'pilot_2': 'Henri Stalter',
#    'pilot_3': ''},
#   18: {'car': 'Bignan ',
#    'brand': '',
#    'engine': 'Moteur Bignan L4 1979cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 88 Tours',
#    'race_turn': '88 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Henri Springuel',
#    'pilot_2': 'René Marie',
#    'pilot_3': ''},
#   19: {'car': 'Chenard et Walcker ',
#    'brand': '',
#    'engine': 'Moteur Chenard et Walker L4 1496cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 83 Tours',
#    'race_turn': '83 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Raymond Glaszmann',
#    'pilot_2': 'Robert Sénéchal',
#    'pilot_3': ''},
#   20: {'car': 'SARA ATS',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1099cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 82 Tours',
#    'race_turn': '82 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Léon Fabert',
#    'pilot_2': 'Lucien Erb',
#    'pilot_3': ''},
#   21: {'car': 'SARA ATS',
#    'brand': '',
#    'engine': 'Moteur SARA L4 1099cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 80 Tours',
#    'race_turn': '80 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': ' Alcain',
#    'pilot_2': 'Julio de Segovia',
#    'pilot_3': ''},
#   22: {'car': 'Aries ',
#    'brand': '',
#    'engine': 'Moteur Aries L4 3117cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 64 Tours',
#    'race_turn': '64 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Robert Laly',
#    'pilot_2': 'Charles Flohot',
#    'pilot_3': ''},
#   23: {'car': 'Rolland Pilain C 23',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1992cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 60 Tours',
#    'race_turn': '60 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '10:20',
#    'race_max_speed': '',
#    'pilot_1': ' Véry',
#    'pilot_2': 'Paul Chalamel',
#    'pilot_3': ''},
#   24: {'car': 'GRP ',
#    'brand': '',
#    'engine': 'Moteur GRP L4 1696cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 59 Tours',
#    'race_turn': '59 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '10:50',
#    'race_max_speed': '',
#    'pilot_1': 'Jean Vaurez',
#    'pilot_2': 'Louis Henry',
#    'pilot_3': ''},
#   25: {'car': 'Corre la Licorne W16',
#    'brand': '',
#    'engine': 'Moteur SCAP L4 1481cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 58 Tours',
#    'race_turn': '58 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Louis Balart',
#    'pilot_2': 'Paul Drouin',
#    'pilot_3': ''},
#   26: {'car': 'Georges Irat 4 A3',
#    'brand': '',
#    'engine': 'Moteur Georges Irat L4 1990cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 42 Tours',
#    'race_turn': '42 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Pierre Malleveau',
#    'pilot_2': 'Jean Douarinou',
#    'pilot_3': ''},
#   27: {'car': 'Montier ',
#    'brand': '',
#    'engine': 'Moteur Ford L4 1995cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 40 Tours',
#    'race_turn': '40 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Albert Ouriou',
#    'pilot_2': 'Charles Montier',
#    'pilot_3': ''},
#   28: {'car': 'Chenard et Walcker ',
#    'brand': '',
#    'engine': 'Moteur Montier L8 3945cc',
#    'tires_brand': '',
#    'category': '3001 a 5000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 26 Tours',
#    'race_turn': '26 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '09:19',
#    'race_max_speed': '',
#    'pilot_1': 'René Léonard',
#    'pilot_2': 'André Lagache',
#    'pilot_3': ''},
#   29: {'car': 'Majola ',
#    'brand': '',
#    'engine': 'Moteur Majola L4 1087cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 22 Tours',
#    'race_turn': '22 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Fernand Casellini',
#    'pilot_2': 'Henri Follot',
#    'pilot_3': ''},
#   30: {'car': 'Rolland Pilain C 23',
#    'brand': '',
#    'engine': 'Moteur Rolland Pillain L4 1992cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 18 Tours',
#    'race_turn': '18 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'René Gaudin',
#    'pilot_2': 'Jean de Marguenat',
#    'pilot_3': ''},
#   31: {'car': 'Alba ',
#    'brand': '',
#    'engine': 'Moteur Alba L4 1481cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 16 Tours',
#    'race_turn': '16 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Bruno Calise',
#    'pilot_2': 'René Dreux',
#    'pilot_3': ''},
#   32: {'car': 'Amilcar CGS',
#    'brand': '',
#    'engine': 'Moteur Amilcar L4 1089cc',
#    'tires_brand': '',
#    'category': '751 a 1100',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 13 Tours',
#    'race_turn': '13 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Marius Mestivier',
#    'pilot_2': 'André Morel',
#    'pilot_3': ''},
#   33: {'car': 'Louis Chenard ',
#    'brand': '',
#    'engine': 'Moteur Chapuis Dornier L4 1496cc',
#    'tires_brand': '',
#    'category': '1001 a 1500',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 13 Tours',
#    'race_turn': '13 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Emile Chenard',
#    'pilot_2': 'Louis Chenard',
#    'pilot_3': ''},
#   34: {'car': 'Omega Six',
#    'brand': '',
#    'engine': 'Moteur Omega L6 1991cc',
#    'tires_brand': '',
#    'category': '1501 a 2000',
#    'race_year': '1924',
#    'try_rank': 'pas de chrono',
#    'try_speed': '',
#    'race_rank': 'Abandon 11 Tours',
# ...
#    'pilot_3': 'Matthieu Lahaye'},
#   33: {'car': 'Aston Martin Vantage AMR',
#    'brand': "D'Station",
#    'engine': 'Moteur Aston Martin V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '58ème - 3:51.107',
#    'try_speed': '212.3 Km/h',
#    'race_rank': '33ème-6e LM GTE Am',
#    'race_turn': '333 Tours - 4536.84 Km ',
#    'race_mean': 'Moyenne 188.9 km/h',
#    'race_best_turn': '3:51.731',
#    'race_max_speed': 'Vitesse Max 302 km/h',
#    'pilot_1': 'Satoshi Hoshino',
#    'pilot_2': 'Tomonobu Fujii',
#    'pilot_3': 'Andrew Watson'},
#   34: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Absolute Racing',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '52ème - 3:50.016',
#    'try_speed': '213.3 Km/h',
#    'race_rank': '34ème-7e LM GTE Am',
#    'race_turn': '332 Tours - 4523.21 Km ',
#    'race_mean': 'Moyenne 188.4 km/h',
#    'race_best_turn': '3:51.384',
#    'race_max_speed': 'Vitesse Max 298 km/h',
#    'pilot_1': 'Andrew Haryanto',
#    'pilot_2': 'Alessio Picariello',
#    'pilot_3': 'Marco Seefried'},
#   35: {'car': 'Aston Martin Vantage AMR',
#    'brand': 'TF Sport',
#    'engine': 'Moteur Aston Martin V8 2T 3982cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '54ème - 3:50.059',
#    'try_speed': '213.2 Km/h',
#    'race_rank': '35ème-8e LM GTE Am',
#    'race_turn': '332 Tours - 4523.25 Km ',
#    'race_mean': 'Moyenne 188.3 km/h',
#    'race_best_turn': '3:50.870',
#    'race_max_speed': 'Vitesse Max 306 km/h',
#    'pilot_1': 'John Hartshorne',
#    'pilot_2': 'Oliver Hancock',
#    'pilot_3': 'Ross Gunn'},
#   36: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'Iron Lynx',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '56ème - 3:50.314',
#    'try_speed': '213 Km/h',
#    'race_rank': '36ème-9e LM GTE Am',
#    'race_turn': '332 Tours - 4523.25 Km ',
#    'race_mean': 'Moyenne 188.1 km/h',
#    'race_best_turn': '3:52.043',
#    'race_max_speed': 'Vitesse Max 299 km/h',
#    'pilot_1': 'Rahel Frey',
#    'pilot_2': 'Sarah Bovy',
#    'pilot_3': 'Michelle Gatting'},
#   37: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'AF Corse',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Pro',
#    'race_year': '2021',
#    'try_rank': '33ème - 3:47.063 (3:46.011)',
#    'try_speed': '216 Km/h',
#    'race_rank': '37ème-5e LM GTE Pro',
#    'race_turn': '331 Tours - 4509.64 Km ',
#    'race_mean': 'Moyenne 187.5 km/h',
#    'race_best_turn': '3:47.809',
#    'race_max_speed': 'Vitesse Max 307 km/h',
#    'pilot_1': 'Daniel Serra',
#    'pilot_2': 'Miguel Molina',
#    'pilot_3': 'Sam Bird'},
#   38: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Herberth Motorsport',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '62ème - 3:52.960',
#    'try_speed': '210.6 Km/h',
#    'race_rank': '38ème-10e LM GTE Am',
#    'race_turn': '330 Tours - 4496 Km ',
#    'race_mean': 'Moyenne 187.1 km/h',
#    'race_best_turn': '3:54.746',
#    'race_max_speed': 'Vitesse Max 299 km/h',
#    'pilot_1': 'Robert Renauer',
#    'pilot_2': 'Ralf Bohn',
#    'pilot_3': 'Rolf Ineichen'},
#   39: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'AF Corse',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '49ème - 3:49.829',
#    'try_speed': '213.4 Km/h',
#    'race_rank': '39ème-11e LM GTE Am',
#    'race_turn': '329 Tours - 4482.35 Km ',
#    'race_mean': 'Moyenne 186.2 km/h',
#    'race_best_turn': '3:50.696',
#    'race_max_speed': 'Vitesse Max 303 km/h',
#    'pilot_1': 'Thomas Flohr',
#    'pilot_2': 'Giancarlo Fisichella',
#    'pilot_3': 'Francesco Castellacci'},
#   40: {'car': 'Oreca 07',
#    'brand': 'United Autosports USA',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '17ème - 3:30.234',
#    'try_speed': '233.3 Km/h',
#    'race_rank': '40ème-18e LM P2',
#    'race_turn': '328 Tours - 4468.57 Km ',
#    'race_mean': 'Moyenne 186 km/h',
#    'race_best_turn': '3:32.263',
#    'race_max_speed': 'Vitesse Max 323 km/h',
#    'pilot_1': 'Philip Hanson',
#    'pilot_2': 'Fabio Scherer',
#    'pilot_3': 'Filipe Albuquerque'},
#   41: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'Inception Racing',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '44ème - 3:49.477 (3:49.462)',
#    'try_speed': '213.8 Km/h',
#    'race_rank': '41ème-12e LM GTE Am',
#    'race_turn': '327 Tours - 4455.12 Km ',
#    'race_mean': 'Moyenne 185.5 km/h',
#    'race_best_turn': '3:50.863',
#    'race_max_speed': 'Vitesse Max 300 km/h',
#    'pilot_1': 'Brendan Iribe',
#    'pilot_2': 'Ollie Millroy',
#    'pilot_3': 'Ben Barnicoat'},
#   42: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Dempsey Proton Racing',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '40ème - 3:47.987 (3:48.620)',
#    'try_speed': '215.2 Km/h',
#    'race_rank': '42ème-13e LM GTE Am',
#    'race_turn': '327 Tours - 4455.08 Km ',
#    'race_mean': 'Moyenne 185.4 km/h',
#    'race_best_turn': '3:51.807',
#    'race_max_speed': 'Vitesse Max 297 km/h',
#    'pilot_1': 'Julien Andlauer',
#    'pilot_2': 'Dominique Bastien',
#    'pilot_3': 'Lance Arnold'},
#   43: {'car': 'Porsche 911 RSR 19',
#    'brand': 'GR Racing',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '41ème - 3:48.560 (3:49.100)',
#    'try_speed': '214.6 Km/h',
#    'race_rank': '43ème-14e LM GTE Am',
#    'race_turn': '322 Tours - 4386.95 Km ',
#    'race_mean': 'Moyenne 182.4 km/h',
#    'race_best_turn': '3:51.084',
#    'race_max_speed': 'Vitesse Max 298 km/h',
#    'pilot_1': 'Michael Wainwright',
#    'pilot_2': 'Ben Barker',
#    'pilot_3': 'Tom Gamble'},
#   44: {'car': 'Chevrolet Corvette C8R',
#    'brand': 'Corvette Racing',
#    'engine': 'Moteur Chevrolet V8 5493cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Pro',
#    'race_year': '2021',
#    'try_rank': '34ème - 3:47.093 (3:47.074)',
#    'try_speed': '216 Km/h',
#    'race_rank': '44ème-6e LM GTE Pro',
#    'race_turn': '313 Tours - 4264.37 Km ',
#    'race_mean': 'Moyenne 177.2 km/h',
#    'race_best_turn': '3:47.501',
#    'race_max_speed': 'Vitesse Max 309 km/h',
#    'pilot_1': 'Tom Milner',
#    'pilot_2': 'Nick Tandy',
#    'pilot_3': 'Alexander Sims'},
#   45: {'car': 'Oreca 07',
#    'brand': 'Team WRT',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '7ème - 3:28.470 (3:29.441)',
#    'try_speed': '235.3 Km/h',
#    'race_rank': 'Non classé-LM P2',
#    'race_turn': '362 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:31.887',
#    'race_max_speed': 'Vitesse Max 321 km/h',
#    'pilot_1': 'Robert Kubica',
#    'pilot_2': 'Louis Delétraz',
#    'pilot_3': 'Yifei Ye'},
#   46: {'car': 'Oreca 07',
#    'brand': 'Risi Competizione',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '19ème - 3:30.418',
#    'try_speed': '233.1 Km/h',
#    'race_rank': 'Non classé 11h22',
#    'race_turn': '275 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:31.646',
#    'race_max_speed': 'Vitesse Max 323 km/h',
#    'pilot_1': 'Ryan Cullen',
#    'pilot_2': 'Oliver Jarvis',
#    'pilot_3': 'Felipe Nasr'},
#   47: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'Rinaldi Racing',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '53ème - 3:50.018',
#    'try_speed': '213.3 Km/h',
#    'race_rank': 'Abandon 12h17',
#    'race_turn': '271 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:52.113',
#    'race_max_speed': 'Vitesse Max 303 km/h',
#    'pilot_1': 'Pierre Ehret',
#    'pilot_2': 'Christian Hook',
#    'pilot_3': 'Jeroen Bleekemolen'},
#   48: {'car': 'Oreca 07',
#    'brand': 'PR1 Motosports Mathiasen',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '14ème - 3:30.123',
#    'try_speed': '233.5 Km/h',
#    'race_rank': 'Abandon 13h24',
#    'race_turn': '261 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:33.805',
#    'race_max_speed': 'Vitesse Max 319 km/h',
#    'pilot_1': 'Patrick Kelly',
#    'pilot_2': 'Gabriel Aubry',
#    'pilot_3': 'Simon Trummer'},
#   49: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Hub Auto Racing',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Pro',
#    'race_year': '2021',
#    'try_rank': '32ème - 3:46.882 (3:47.599)',
#    'try_speed': '216.2 Km/h',
#    'race_rank': 'Abandon 08h35',
#    'race_turn': '227 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:50.923',
#    'race_max_speed': 'Vitesse Max 300 km/h',
#    'pilot_1': 'Dries Vanthoor',
#    'pilot_2': 'Alvaro Parente',
#    'pilot_3': 'Maxime Martin'},
#   50: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Weathertech Racing',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Pro',
#    'race_year': '2021',
#    'try_rank': '38ème - 3:47.682',
#    'try_speed': '215.4 Km/h',
#    'race_rank': 'Abandon 02h46',
#    'race_turn': '139 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:49.579',
#    'race_max_speed': 'Vitesse Max 303 km/h',
#    'pilot_1': 'Cooper Macneil',
#    'pilot_2': 'Earl Bamber',
#    'pilot_3': 'Laurens Vanthoor'},
#   51: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Team Project 1',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '59ème - 3:51.411',
#    'try_speed': '212 Km/h',
#    'race_rank': 'Abandon 03h17',
#    'race_turn': '138 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:54.418',
#    'race_max_speed': 'Vitesse Max 295 km/h',
#    'pilot_1': 'Dennis Olsen',
#    'pilot_2': 'Anders Buchardt',
#    'pilot_3': 'Robert Foley'},
#   52: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'Kessel Racing',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '47ème - 3:49.715',
#    'try_speed': '213.5 Km/h',
#    'race_rank': 'Abandon 01h47',
#    'race_turn': '128 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:51.064',
#    'race_max_speed': 'Vitesse Max 302 km/h',
#    'pilot_1': 'Takeshi Kimura',
#    'pilot_2': 'Scott Andrews',
#    'pilot_3': 'Mikkel Jensen'},
#   53: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'JMW Motorsport',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '61ème - 3:52.304',
#    'try_speed': '211.2 Km/h',
#    'race_rank': 'Abandon 01h47',
#    'race_turn': '117 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:52.744',
#    'race_max_speed': 'Vitesse Max 298 km/h',
#    'pilot_1': 'Thomas Neubauer',
#    'pilot_2': 'Rodrigo Sales',
#    'pilot_3': 'Jody Fannin'},
#   54: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'Spirit Of Race',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '60ème - 3:52.088',
#    'try_speed': '211.4 Km/h',
#    'race_rank': 'Abandon 01h14',
#    'race_turn': '109 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:52.793',
#    'race_max_speed': 'Vitesse Max 299 km/h',
#    'pilot_1': 'Duncan Cameron',
#    'pilot_2': 'David Perel',
#    'pilot_3': 'Matthew Griffin'},
#   55: {'car': 'Aurus 01',
#    'brand': 'G-Drive Racing',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '24ème - 3:31.203',
#    'try_speed': '232.3 Km/h',
#    'race_rank': 'Abandon 00h37',
#    'race_turn': '108 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:35.212',
#    'race_max_speed': 'Vitesse Max 321 km/h',
#    'pilot_1': 'John Falb',
#    'pilot_2': 'Roberto Merhi',
#    'pilot_3': 'Rui Andrade'},
#   56: {'car': 'Ferrari 488 GTE EVO',
#    'brand': 'Cetilar Racing',
#    'engine': 'Moteur Ferrari V8 2T 3996cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '43ème - 3:49.387 (3:49.102)',
#    'try_speed': '213.8 Km/h',
#    'race_rank': 'Abandon 22h57',
#    'race_turn': '90 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:51.354',
#    'race_max_speed': 'Vitesse Max 303 km/h',
#    'pilot_1': 'Roberto Lacorte',
#    'pilot_2': 'Giorgio Sernagiotto',
#    'pilot_3': 'Antonio Fuoco'},
#   57: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Team Project 1',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '42ème - 3:48.876 (3:49.608)',
#    'try_speed': '214.3 Km/h',
#    'race_rank': 'Abandon 22h07',
#    'race_turn': '84 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:52.210',
#    'race_max_speed': 'Vitesse Max 298 km/h',
#    'pilot_1': 'Egidio Perfetti',
#    'pilot_2': 'Matteo Cairoli',
#    'pilot_3': 'Riccardo Pera'},
#   58: {'car': 'Oreca 07',
#    'brand': 'United Autosports',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '10ème - 3:29.078 (3:29.688)',
#    'try_speed': '234.6 Km/h',
#    'race_rank': 'Abandon 22h45',
#    'race_turn': '75 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:34.196',
#    'race_max_speed': 'Vitesse Max 319 km/h',
#    'pilot_1': 'Nicolas Jamin',
#    'pilot_2': 'Jonathan Aberdein',
#    'pilot_3': 'Manuel Maldonado'},
#   59: {'car': 'Oreca 07',
#    'brand': 'Richard Mille Racing Team',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '28ème - 3:32.598',
#    'try_speed': '230.7 Km/h',
#    'race_rank': 'Abandon 22h06',
#    'race_turn': '74 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:35.137',
#    'race_max_speed': 'Vitesse Max 315 km/h',
#    'pilot_1': 'Tatiana Calderón',
#    'pilot_2': 'Sophia Flörsch',
#    'pilot_3': 'Beitske Visser'},
#   60: {'car': 'Porsche 911 RSR 19',
#    'brand': 'Proton Competition',
#    'engine': 'Moteur Porsche F6 4194cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '48ème - 3:49.788',
#    'try_speed': '213.5 Km/h',
#    'race_rank': 'Abandon 20h16',
#    'race_turn': '66 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:53.285',
#    'race_max_speed': 'Vitesse Max 296 km/h',
#    'pilot_1': 'Harry Tincknell',
#    'pilot_2': 'Vutthikorn Inthraphuvasak',
#    'pilot_3': 'Florian Latorre'},
#   61: {'car': 'Aston Martin Vantage AMR',
#    'brand': 'Aston Martin Racing',
#    'engine': 'Moteur Aston Martin V8 2T 3982cc',
#    'tires_brand': 'Michelin',
#    'category': 'LM GTE Am',
#    'race_year': '2021',
#    'try_rank': '55ème - 3:50.156',
#    'try_speed': '213.1 Km/h',
#    'race_rank': 'Abandon 19h53',
#    'race_turn': '45 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '3:51.740',
#    'race_max_speed': 'Vitesse Max 303 km/h',
#    'pilot_1': 'Paul Dalla Lana',
#    'pilot_2': 'Nicki Thiim',
#    'pilot_3': 'Marcos Gomes'},
#   62: {'car': 'Oreca 07',
#    'brand': 'Idec Sport',
#    'engine': 'Moteur Gibson V8 4200cc',
#    'tires_brand': 'Good Year',
#    'category': 'LM P2',
#    'race_year': '2021',
#    'try_rank': '21ème - 3:30.709',
#    'try_speed': '232.8 Km/h',
#    'race_rank': 'Non Partant-LM P2',
#    'race_turn': '0 Tours - 0 Km ',
#    'race_mean': '',
#    'race_best_turn': '',
#    'race_max_speed': '',
#    'pilot_1': 'Dwight Merriman',
#    'pilot_2': 'Thomas Laurent',
#    'pilot_3': 'Ryan Dalziel'}}}
